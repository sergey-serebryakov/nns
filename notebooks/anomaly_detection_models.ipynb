# %% [markdown]
# # Various small models for time series anomaly detection
#
# A number of simple models from some of the projects related to detecting anomalies in sensor data.

# %%
from nns.nns import (estimate, printable_dataframe)
from nns.models.anomaly_detection import (FullyConnectedAutoencoder, LSTMForecaster, LSTMAutoencoder)

# %%
inference = []
training = []

# %% [markdown]
# # Fully-connected autoencoder

# %%
estimate(FullyConnectedAutoencoder(), inference, training)
# Out:
#           name out_shape    gFLOPs  num_params  num_activations  \
# 0        input    (369,)  0.000000           0              369
# 1  enc/dense01    (128,)  0.000047       47360              256
# 2  enc/dense02     (64,)  0.000008        8256              128
# 3  enc/dense03     (16,)  0.000001        1040               32
# 4  dec/dense01     (64,)  0.000001        1088              128
# 5  dec/dense02    (128,)  0.000008        8320              256
# 6  dec/dense03    (369,)  0.000047       47601              369
# 7        TOTAL    (369,)  0.000113      113665             1538
#
#    params_mem (MB)  activations_mem (MB)
# 0         0.000000              0.001476
# 1         0.189440              0.001024
# 2         0.033024              0.000512
# 3         0.004160              0.000128
# 4         0.004352              0.000512
# 5         0.033280              0.001024
# 6         0.190404              0.001476
# 7         0.454660              0.006152

# %% [markdown]
# # LSTM Forecaster

# %%
estimate(LSTMForecaster(), inference, training)
# Out:
# Layer not recognized (type=<class 'tensorflow.python.keras.engine.input_layer.InputLayer'>, name=input)
#             name out_shape    gFLOPs  num_params  num_activations  \
# 0          input   (9, 41)  0.000000           0              369
# 1  lstm01 (LSTM)  (9, 128)  0.000779       87040            16128
# 2  lstm02 (LSTM)    (128,)  0.001180      131584            16128
# 3         output     (41,)  0.000005        5289               41
# 4          TOTAL     (41,)  0.001964      223913            32666
#
#    params_mem (MB)  activations_mem (MB)
# 0         0.000000              0.001476
# 1         0.348160              0.064512
# 2         0.526336              0.064512
# 3         0.021156              0.000164
# 4         0.895652              0.130664

# %% [markdown]
# # LSTM Autoencoder

# %%
estimate(LSTMAutoencoder(), inference, training)
# Out:
# Layer not recognized (type=<class 'tensorflow.python.keras.engine.input_layer.InputLayer'>, name=input)
#                  name  out_shape        gFLOPs  num_params  num_activations  \
# 0               input  (100, 41)  0.000000e+00           0             4100
# 1   enc/lstm01 (LSTM)  (100, 64)  2.688000e-03       27136            89600
# 2   enc/lstm02 (LSTM)  (100, 32)  1.228800e-03       12416            44800
# 3   enc/lstm03 (LSTM)      (16,)  3.072000e-04        3136            22400
# 4         enc/dense04      (16,)  2.560000e-07         272               16
# 5          enc/repeat  (100, 16)  0.000000e+00           0             1600
# 6   dec/lstm01 (LSTM)  (100, 16)  2.048000e-04        2112            22400
# 7   dec/lstm02 (LSTM)  (100, 32)  6.144000e-04        6272            44800
# 8   dec/lstm03 (LSTM)  (100, 64)  2.457600e-03       24832            89600
# 9         dec/dense04      (41,)  2.624000e-04        2665             4100
# ...

# %% [markdown]
# ### Summary: inference

# %%
printable_dataframe(inference)
# Out:
#                        Model Input shape  #Parameters  Model size (MB) FP32  \
# 0  FullyConnectedAutoencoder      (369,)       113665              0.454660
# 1              LSTMPredictor   (100, 41)       223913              0.895652
# 2            LSTMAutoencoder   (100, 41)        78841              0.315364
#
#    GFLOPs (multiply-add)  Activation size (MB) FP32
# 0               0.000113                   0.006152
# 1               0.021765                   1.450164
# 2               0.007763                   1.293664

# %% [markdown]
# ### Summary: training

# %%
printable_dataframe(training)
# Out:
#                        Model Input shape  #Parameters  Model size (MB) FP32  \
# 0  FullyConnectedAutoencoder      (369,)       113665              0.454660
# 1             LSTMForecaster     (9, 41)       223913              0.895652
# 2            LSTMAutoencoder   (100, 41)        78841              0.315364
#
#    GFLOPs (multiply-add)  Activation size (MB) FP32
# 0               0.000339                   0.012304
# 1               0.005891                   0.261328
# 2               0.023290                   2.587328
