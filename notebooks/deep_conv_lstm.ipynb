# %% [markdown]
# # Deep Convolutional and LSTM Recurrent Neural Networks for Multimodal Wearable Activity Recognition, Sensors 2016
#
# One of the models considered in MLPerf DeepTS [proposal](http://bit.ly/2GIUcb3). Paper is [here](https://www.mdpi.com/1424-8220/16/1/115/htm). Code is [here](https://github.com/sussexwearlab/DeepConvLSTM).
#
# ![Neural network model](https://res.mdpi.com/sensors/sensors-16-00115/article_deploy/html/images/sensors-16-00115-g003.png)

# %%
from nns.nns import (estimate, printable_dataframe)
from nns.models.activity_recognition import DeepConvLSTMModel

# %%
perf = []
estimate(DeepConvLSTMModel(), perf, perf)
# Out:
#            name      out_shape    gFLOPs  num_params  num_activations  \
# 0         input   (24, 113, 1)  0.000000           0             2712
# 1     conv1/5x1  (20, 113, 64)  0.000723         384           289280
# 2     conv2/5x1  (16, 113, 64)  0.037028       20544           231424
# 3     conv3/5x1  (12, 113, 64)  0.027771       20544           173568
# 4     conv4/5x1   (8, 113, 64)  0.018514       20544           115712
# 5       reshape      (8, 7232)  0.000000           0            57856
# 6  lstm1 (LSTM)       (8, 128)  0.030147     3768832            14336
# 7  lstm2 (LSTM)         (128,)  0.001049      131584            14336
# 8          prob          (18,)  0.000002        2322               36
# 9         TOTAL          (18,)  0.115233     3964754           899260
#
#    params_mem (MB)  activations_mem (MB)
# 0         0.000000              0.010848
# 1         0.001536              1.157120
# 2         0.082176              0.925696
# 3         0.082176              0.694272
# 4         0.082176              0.462848
# 5         0.000000              0.231424
# 6        15.075328              0.057344
# 7         0.526336              0.057344
# 8         0.009288              0.000144
# 9        15.859016              3.597040

# %%
printable_dataframe(perf, ignore_phase=False)
# Out:
#                Model      Phase   Input shape  #Parameters  \
# 0  DeepConvLSTMModel  inference  (24, 113, 1)      3964754
# 1  DeepConvLSTMModel   training  (24, 113, 1)      3964754
#
#    Model size (MB) FP32  GFLOPs (multiply-add)  Activation size (MB) FP32
# 0             15.859016               0.115233                    3.59704
# 1             15.859016               0.345700                    7.19408
